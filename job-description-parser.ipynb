# %%
# import modules
import nltk
from nltk.tokenize import WhitespaceTokenizer
from nltk.probability import FreqDist
from nltk import bigrams, trigrams
from nltk.collocations import *
import glob

# import stopwords corpus
stopwords = nltk.corpus.stopwords.words('english')

# define data sources
dir = 'data/joblistings/director_analytics/*.txt'
file = 'data/single/job_description.txt'

# init
tokens = []
raw=''

# start file open routine
print('Loading files:\n')

## if single file, uncomment these lines
#f = open(file)
#raw = f.read()

## if multiple files, uncomment these lines
files = glob.glob(dir)
for name in files:
    print(name)
    with open(name) as f:
        raw += ('\n' + f.read())

# end file open routine

raw_tokens = WhitespaceTokenizer().tokenize(raw)

# filter out stopwords
for t in raw_tokens:
    if t.lower() not in stopwords:
        tokens.append(t.lower())

# build nltk units
raw_text = nltk.Text(raw_tokens)
text = nltk.Text(tokens)
vocab = sorted(set(text))
dist = FreqDist(text)

# stats
print('Total words (unfiltered):', len(raw_tokens))
print('Total words (filtered):', len(tokens))

# Top keywords
common_25 = dist.most_common(25)

print('Top keywords & count:\n')
for x in common_25:
    print(': '.join(map(str,x)))

# Find collocations

## bigrams
bigram_measures = nltk.collocations.BigramAssocMeasures()
bi_finder = BigramCollocationFinder.from_words(text, 2) # search window
bi_finder.apply_freq_filter(3) # number of recurrences
bigrams = bi_finder.nbest(bigram_measures.likelihood_ratio, 1000)

print('Top Bigrams:\n',)
for x in bigrams:
    print(' '.join(x))

## trigrams
trigram_measures = nltk.collocations.TrigramAssocMeasures()
tri_finder = TrigramCollocationFinder.from_words(text, 3)
tri_finder.apply_freq_filter(2)
trigrams = tri_finder.nbest(trigram_measures.likelihood_ratio, 1000)

print('Top Trigrams:\n',)
for x in trigrams:
    print(' '.join(x))
# Out:
# Loading files:
#
# data/joblistings/director_analytics/A+E - Director Data Analytics.txt
# data/joblistings/director_analytics/Creative Circle - Digital Data Analytics Director.txt
# data/joblistings/director_analytics/Dentsu Aegis - VP Director Digital Analytics.txt
# data/joblistings/director_analytics/FCB Global - Strategic Analytics Director.txt
# data/joblistings/director_analytics/Generator - Director Analytics.txt
# data/joblistings/director_analytics/Harnham - Director Digital Analytics.txt
# data/joblistings/director_analytics/IPG Mediabrands - Director Advanced Analytics.txt
# data/joblistings/director_analytics/Ketchup - VP Research and Analytics.txt
# data/joblistings/director_analytics/MediaAssociates - Director Insights Analytics.txt
# data/joblistings/director_analytics/MediaMath - Director Account Analytics.txt
# data/joblistings/director_analytics/Merkle - Senior Director Data Analytics and Platforms.txt
# data/joblistings/director_analytics/Mindshare - Director Marketing Sciences Data Strategy.txt
# data/joblistings/director_analytics/MKTG - Director Digital Analytics.txt
# data/joblistings/director_analytics/Perficient - Director of Strategy and Innovation.txt
# data/joblistings/director_analytics/Smith Hanley - Director of Digital Marketing Analytics.txt
# data/joblistings/director_analytics/Starcom - Director Business Intelligence.txt
# data/joblistings/director_analytics/TDA Creative - Associate Director Analytics and Marketing Intelligence.txt
# Total words (unfiltered): 9076
# Total words (filtered): 6291
# Top keywords & count:
#
# data: 102
# analytics: 94
# experience: 70
# digital: 69
# business: 66
# client: 65
# media: 58
# team: 58
# marketing: 58
# clients: 44
# new: 37
# ability: 34
# lead: 34
# work: 32
# measurement: 29
# analytics,: 29
# agency: 29
# social: 29
# skills: 28
# &: 27
# working: 27
# tools: 27
# strong: 26
# insights: 26
# strategic: 26
# Top Bigrams:
#
# job description
# track record
# thought leadership
# social listening
# ideal candidate
# 3rd party
# tag manager,
# written verbal
# crimson hexagon,
# lead team
# years’ experience
# communication skills
# verbal communication
# social media
# project management,
# team members
# thorough understanding
# must possess
# value proposition
# working closely
# excellent written
# digital media
# team analysts
# internal external
# new business
# 3+ years
# 5+ years
# bachelor’s degree
# best practices
# microsoft excel
# successful candidate
# presentation skills
# proven track
# web analytics
# actionable insights
# business goals
# direct reports
# google tag
# work closely
# ad tech
# cross-functional teams
# big data
# analytics, adobe
# knowledge sharing
# digital marketing
# omniture, google
# experience analyzing
# plus experience
# analytics director
# data collection
# data science
# google analytics,
# website analytics
# marketing sciences
# large data
# senior leadership
# business pitches
# evaluate new
# traditional digital
# ability manage
# analysis reporting
# director digital
# google analytics
# insights recommendations
# client engagements
# data visualization
# working within
# digital analytics
# experience working
# research projects
# ability work
# data analytics
# proven ability
# internal teams
# skills excellent
# director, digital
# experience managing
# management skills
# years experience
# years working
# marketing campaigns
# advanced analytics
# research measurement
# analytics seo
# digital data
# business development
# digital analytics,
# digital social
# clients internal
# business opportunities
# skills ability
# strategic analytics
# analytics tools
# & analytics
# data analysis
# data &
# media research
# experience digital
# understanding digital
# marketing analytics
# media analytics
# media agency
# social analytics
# analytics team
# analytics experience
# Top Trigrams:
#
# job description director
# proven track record
# written verbal communication
# excellent written verbal
# google tag manager,
# verbal communication skills
# provide thought leadership
# crimson hexagon, meltwater,
# 3rd party data,
# (such crimson hexagon,
# eight years’ experience
# traditional digital media
# must possess 3
# new business pitches
# meeting exceeding expectations;
# smith hanley associates
# 8+ years’ experience
# passionate telling stories
# (search, display, email)
# small team analysts
# director digital marketing
# bachelor’s degree required,
# $160,000 - $170,000
# skills excellent written
# (google analytics, adobe
# website analytics seo
# functioning teams comprised
# digital media campaigns
# minimum eight years’
# new business opportunities,
# possess 3 plus
# 3+ years experience
# plus bachelor’s degree
# mining large data
# teams comprised perficient
# telling stories data
# digital data &
# communication presentation skills
# presentation skills ability
# & analytics director
# digital marketing analytics
# highly functioning teams
# digital marketing analytics:
# web analytics tools
# comprised perficient client
# marketing mix modeling,
# 3 plus years
# cross-media measurement strategy
# analytics, adobe analytics,
# years working within
# strategic analytics director
# closely data scientists
# management skills excellent
# director, digital analytics,
# senior level clients
# clients internal teams
# data management, providing
# data & analytics
# site analytics tools
# years experience digital
# experience digital analytics
# strategic analytics capabilities
# clients identify business
